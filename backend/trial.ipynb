# %%
import torch

# Load state dict
state_dict = torch.load('efficientnet_brain_tumor.pth', map_location=torch.device('cpu'))
total_params = sum(v.numel() for v in state_dict.values())
print(f"Total Parameters: {total_params}")
# Out:
# Total Parameters: 4054737
